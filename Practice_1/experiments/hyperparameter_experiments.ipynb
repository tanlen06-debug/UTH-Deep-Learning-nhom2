# %% [markdown]
# # 8. Hyperparameter Experiments
#
# This notebook compares three neural network configurations for FashionMNIST classification.
#
# The experiments investigate the effects of:
#  Hidden layer size
#  Learning rate
#  Optimizer

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Device:", device)
# Out:
# Device: cpu

# %%
experiment_configs = [
    {
        "model": "Model 1",
        "hidden1": 128,
        "hidden2": 64,
        "learning_rate": 0.001,
        "optimizer": "Adam"
    },
    {
        "model": "Model 2",
        "hidden1": 256,
        "hidden2": 128,
        "learning_rate": 0.001,
        "optimizer": "Adam"
    },
    {
        "model": "Model 3",
        "hidden1": 128,
        "hidden2": 64,
        "learning_rate": 0.01,
        "optimizer": "SGD"
    }
]

for config in experiment_configs:
    print(config)
# Out:
# {'model': 'Model 1', 'hidden1': 128, 'hidden2': 64, 'learning_rate': 0.001, 'optimizer': 'Adam'}
# {'model': 'Model 2', 'hidden1': 256, 'hidden2': 128, 'learning_rate': 0.001, 'optimizer': 'Adam'}
# {'model': 'Model 3', 'hidden1': 128, 'hidden2': 64, 'learning_rate': 0.01, 'optimizer': 'SGD'}

# %%
results = [
    {
        "Model": "Model 1",
        "Hidden layers": "128-64",
        "LR": 0.001,
        "Optimizer": "Adam",
        "Accuracy": None,
        "Final Loss": None
    },
    {
        "Model": "Model 2",
        "Hidden layers": "256-128",
        "LR": 0.001,
        "Optimizer": "Adam",
        "Accuracy": None,
        "Final Loss": None
    },
    {
        "Model": "Model 3",
        "Hidden layers": "128-64",
        "LR": 0.01,
        "Optimizer": "SGD",
        "Accuracy": None,
        "Final Loss": None
    }
]

results
# Out:
# [{'Model': 'Model 1',
#   'Hidden layers': '128-64',
#   'LR': 0.001,
#   'Optimizer': 'Adam',
#   'Accuracy': None,
#   'Final Loss': None},
#  {'Model': 'Model 2',
#   'Hidden layers': '256-128',
#   'LR': 0.001,
#   'Optimizer': 'Adam',
#   'Accuracy': None,
#   'Final Loss': None},
#  {'Model': 'Model 3',
#   'Hidden layers': '128-64',
#   'LR': 0.01,
#   'Optimizer': 'SGD',
#   'Accuracy': None,
#   'Final Loss': None}]

# %% [markdown]
# ## Experiment 1 – Baseline Model
#
#  Hidden layers: 128 → 64
#  Learning rate: 0.001
#  Optimizer: Adam
#
# This experiment is used as the baseline for comparison.
#
# ## Experiment 2 – Larger Hidden Layers
#
#  Hidden layers: 256 → 128
#  Learning rate: 0.001
#  Optimizer: Adam
#
# This experiment examines whether increasing the number of neurons improves model performance.
#
# ## Experiment 3 – SGD Optimizer
#
#  Hidden layers: 128 → 64
#  Learning rate: 0.01
#  Optimizer: SGD
#
# This experiment examines the effect of changing the optimizer and learning rate.
