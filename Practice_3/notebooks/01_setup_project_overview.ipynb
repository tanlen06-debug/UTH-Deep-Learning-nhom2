# %% [markdown]
# # Practice 3 - Setup & Project Overview
#
# ## Owner
# TV1 - Group Leader
#
# ## Responsibility
# - Introduce the Practice 3 objectives and workflow.
# - Verify the common environment and required libraries.
# - Record the agreed dataset/model choices for Exercise 2.
# - Check that notebooks 02-06 follow one consistent pipeline.
# - Perform final integration and quality checks.
#
# ## Practice 3 pipeline
# Exercise 1: Sentiment Analysis with Hugging Face.
# Exercise 2: Binary Text Classification Fine-tuning.
#
# ## Integration checklist
# - [ ] Environment and dependencies are consistent
# - [ ] Exercise 1 is complete
# - [ ] Dataset and preprocessing are complete
# - [ ] Model and tokenizer are compatible
# - [ ] Fine-tuning runs successfully
# - [ ] Evaluation is complete
# - [ ] All notebooks run without errors

# %%
print('Practice 3 - project integration check')

# %% [markdown]
# ## Final summary
# Add the final agreed configuration, important results, and presentation notes here.
