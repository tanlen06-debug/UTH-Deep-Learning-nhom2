# %% [markdown]
# # Practice 3 - TV1 Group Leader / Integration
#
# ## Responsibility
# - Manage and integrate all Practice 3 components.
# - Verify Exercise 1 and Exercise 2 notebooks.
# - Check dependencies, outputs, paths, and final presentation readiness.
#
# ## Final checklist
# - [ ] Exercise 1 completed
# - [ ] Exercise 2 dataset/preprocessing completed
# - [ ] Pretrained model and tokenizer verified
# - [ ] Fine-tuning completed
# - [ ] Evaluation completed
# - [ ] All notebooks run without errors

# %%
# Final integration checks can be added here.
print('Practice 3 integration notebook')

# %% [markdown]
# ## Final notes
# Add the final summary, important results, and presentation notes here.
