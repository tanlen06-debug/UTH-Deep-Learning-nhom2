# %% [markdown]
# # 05 — Training & TensorBoard
#
# **Mục tiêu:** Training engine, validation, checkpoint và TensorBoard.
#
# > Chạy notebook từ đầu đến cuối trước khi tạo Pull Request.

# %%
from pathlib import Path

# Tự tìm thư mục Practice_2, không dùng đường dẫn C:\\ hoặc D:\\
PROJECT_DIR = Path.cwd()
while PROJECT_DIR.name != 'Practice_2' and PROJECT_DIR.parent != PROJECT_DIR:
    PROJECT_DIR = PROJECT_DIR.parent

print('PROJECT_DIR:', PROJECT_DIR)

# %% [markdown]
# ## Checklist
# - [ ] Code chạy được
# - [ ] Có output
# - [ ] Có nhận xét kết quả
# - [ ] Không dùng đường dẫn tuyệt đối
# - [ ] Không đưa dữ liệu, checkpoint hoặc TensorBoard log lớn lên GitHub
